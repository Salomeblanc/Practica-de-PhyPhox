# %%
import pandas as pd
import matplotlib.pyplot as plt

# Leer el archivo CSV
datos = pd.read_csv("Data.csv")

# Mostrar las primeras filas para verificar que se leyó correctamente
print(datos.head())
# Gráfica de velocidad angular
plt.figure(figsize=(8,5))
plt.plot(datos["Time (s)"], datos["Angular velocity (rad/s)"], marker="o")
plt.title("Velocidad Angular vs Tiempo")
plt.xlabel("Tiempo (s)")
plt.ylabel("Velocidad Angular (rad/s)")
plt.grid(True)
plt.show()

# Gráfica de aceleración
plt.figure(figsize=(8,5))
plt.plot(datos["Time (s)"], datos["Acceleration (m/s^2)"], marker="o")
plt.title("Aceleración vs Tiempo")
plt.xlabel("Tiempo (s)")
plt.ylabel("Aceleración (m/s²)")
plt.grid(True)
plt.show()
# Out:
#    Time (s)  Angular velocity (rad/s)  Acceleration (m/s^2)
# 0  0.679145                  0.019458              0.062556
# 1  1.176811                  0.677431              0.403326
# 2  1.674503                  0.208682              0.494564
# 3  2.172219                  0.242943              1.584505
# 4  2.919911                  3.196535              8.305855
